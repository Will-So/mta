# %%
# !ls
# Out:
# 02_Will.ipynb              README.md                  data                       turnstiles.py
# Exploratory Analysis.ipynb all_turnstiles.py          mta_challenge_3.ipynb      turnstiles.py.orig

# %%
from all_turnstiles import generate_df

# %%
df = generate_df()
# Out:
# /Users/Will/anaconda/envs/py27/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
# /Users/Will/anaconda/envs/py27/lib/python2.7/site-packages/pandas/core/generic.py:2177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#      ca  unit       scp        station linename division        date  \
# 0  A002  R051  02-00-00  LEXINGTON AVE   456NQR      BMT  12/27/2014
# 1  A002  R051  02-00-00  LEXINGTON AVE   456NQR      BMT  12/27/2014
# 2  A002  R051  02-00-00  LEXINGTON AVE   456NQR      BMT  12/27/2014
# 3  A002  R051  02-00-00  LEXINGTON AVE   456NQR      BMT  12/27/2014
# ...

# %%
df
# Out:
#                          station            datetime        date      time  \
# 1        (LEXINGTON AVE, 456NQR) 2014-12-27 11:00:00  12/27/2014  11:00:00
# 2        (LEXINGTON AVE, 456NQR) 2014-12-27 15:00:00  12/27/2014  15:00:00
# 3        (LEXINGTON AVE, 456NQR) 2014-12-27 19:00:00  12/27/2014  19:00:00
# 4        (LEXINGTON AVE, 456NQR) 2014-12-27 23:00:00  12/27/2014  23:00:00
# 5        (LEXINGTON AVE, 456NQR) 2014-12-28 03:00:00  12/28/2014  03:00:00
# 6        (LEXINGTON AVE, 456NQR) 2014-12-28 07:00:00  12/28/2014  07:00:00
# 7        (LEXINGTON AVE, 456NQR) 2014-12-28 11:00:00  12/28/2014  11:00:00
# 8        (LEXINGTON AVE, 456NQR) 2014-12-28 15:00:00  12/28/2014  15:00:00
# 9        (LEXINGTON AVE, 456NQR) 2014-12-28 19:00:00  12/28/2014  19:00:00
# 10       (LEXINGTON AVE, 456NQR) 2014-12-28 23:00:00  12/28/2014  23:00:00
# 11       (LEXINGTON AVE, 456NQR) 2014-12-29 03:00:00  12/29/2014  03:00:00
# ...
